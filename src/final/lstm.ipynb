# %%
import pandas as pd

file_path = "C:\\Users\\v0166\\Github\\Introduction_to_AI_Homework\\2023_fut.csv"
data = pd.read_csv(file_path, encoding='big5')

print(data.info())  # 查看列的資料類型資訊
data.head()  # 查看前5筆資料
# Out:
# C:\Users\v0166\AppData\Local\Temp\ipykernel_10336\4194133361.py:4: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, encoding='big5')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451348 entries, 0 to 451347
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   交易日期         451348 non-null  object
#  1   契約           451347 non-null  object
#  2   到期月份(週別)     451347 non-null  object
#  3   開盤價          451347 non-null  object
#  4   最高價          451347 non-null  object
#  5   最低價          451347 non-null  object
#  6   收盤價          451347 non-null  object
#  7   漲跌價          451347 non-null  object
#  8   漲跌%          451347 non-null  object
#  9   成交量          451347 non-null  float64
#  10  結算價          451347 non-null  object
#  11  未沖銷契約數       451347 non-null  object
#  12  最後最佳買價       451347 non-null  object
# ...

# %%
import os

data_dir = "C:\\Users\\v0166\\Github\\Introduction_to_AI_Homework\\data\\final"
file_names = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
data_files = [os.path.join(data_dir, f) for f in file_names]
output_folder = "output_files/"
os.makedirs(output_folder, exist_ok=True)
print(file_names)
# Out:
# ['2014_fut.csv', '2015_fut.csv', '2016_fut.csv', '2017_fut.csv', '2018_fut.csv', '2019_fut.csv', '2020_fut.csv', '2021_fut.csv', '2022_fut.csv', '2023_fut.csv']

# %%
for file_name in data_files:
    file_path = os.path.join(file_path, file_name)
    data = pd.read_csv(file_path, encoding='big5')

    # 檢查數據中是否包含 '契約' 列
    if '契約' not in data.columns:
        raise ValueError("數據中缺少 '契約' 列，請檢查數據結構。")

    # 按契約分組並保存數據
    for contract, group in data.groupby('契約'):
        # 替換契約名稱中的非法字元
        safe_contract_name = re.sub(r'[\\/*?:"<>|]', '_', contract)
        output_file = os.path.join(output_folder, f"{safe_contract_name}.csv")
        
        # 如果檔案存在，則追加數據；如果不存在，則新建文件
        group.to_csv(output_file, index=False, encoding='utf-8-sig', mode='a' if os.path.exists(output_file) else 'w')
        print(f"已保存檔案：{output_file}，共 {len(group)} 筆數據")

print("完成！所有契約數據已分別保存。")
# Out:
# 已保存檔案：output_files/BRF.csv，共 2417 筆數據
# 已保存檔案：output_files/BTF.csv，共 1502 筆數據
# 已保存檔案：output_files/CAF.csv，共 1402 筆數據
# 已保存檔案：output_files/CBF.csv，共 1598 筆數據
# 已保存檔案：output_files/CCF.csv，共 1946 筆數據
# 已保存檔案：output_files/CDF.csv，共 2974 筆數據
# 已保存檔案：output_files/CE1.csv，共 254 筆數據
# 已保存檔案：output_files/CEF.csv，共 1549 筆數據
# 已保存檔案：output_files/CFF.csv，共 1435 筆數據
# 已保存檔案：output_files/CGF.csv，共 1469 筆數據
# 已保存檔案：output_files/CH1.csv，共 150 筆數據
# 已保存檔案：output_files/CHF.csv，共 1584 筆數據
# 已保存檔案：output_files/CJF.csv，共 1293 筆數據
# 已保存檔案：output_files/CK1.csv，共 333 筆數據
# 已保存檔案：output_files/CKF.csv，共 1597 筆數據
# 已保存檔案：output_files/CL1.csv，共 172 筆數據
# 已保存檔案：output_files/CL2.csv，共 9 筆數據
# 已保存檔案：output_files/CLF.csv，共 1411 筆數據
# 已保存檔案：output_files/CM1.csv，共 100 筆數據
# 已保存檔案：output_files/CMF.csv，共 1364 筆數據
# 已保存檔案：output_files/CNF.csv，共 1496 筆數據
# 已保存檔案：output_files/CQF.csv，共 1410 筆數據
# 已保存檔案：output_files/CRF.csv，共 1364 筆數據
# 已保存檔案：output_files/CSF.csv，共 1783 筆數據
# 已保存檔案：output_files/CUF.csv，共 1383 筆數據
# ...
